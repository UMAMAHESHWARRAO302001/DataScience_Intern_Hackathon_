# %% [markdown]
# # UMAMAHESH YENAMALA Answers for DataScience Hackathon - Junior data scientist

# %%
import pandas as pd
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\dell\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df_link=pd.read_csv("links.csv")

# %% [markdown]
# ## What is the shape of "movies.csv"?

# %%
df_link.shape
# Out:
# (9742, 3)

# %%
df_movies = pd.read_csv("movies.csv")

# %% [markdown]
# ## What is the shape of "movies.csv"?

# %%
df_movies.shape
# Out:
# (9742, 3)

# %%
df_ratings= pd.read_csv("ratings.csv")

# %% [markdown]
# ## What is the shape of "ratings.csv"?

# %%
df_ratings.shape
# Out:
# (100836, 4)

# %%
df_tags=pd.read_csv("tags.csv")

# %%
df_tags.shape
# Out:
# (3683, 4)

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_link.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# ## How many unique "userId" are available in "ratings.csv"?

# %%
df_ratings['userId'].nunique()
# Out:
# 610

# %%
df_movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
df_ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df_ratings['rating'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
merged_movie_rating = pd.merge(df_movies, df_ratings, on='movieId')

# %% [markdown]
# ## What is the shape of "ratings.csv"?

# %%
merged_movie_rating.shape
# Out:
# (100836, 6)

# %%
merged_movie_rating.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %% [markdown]
# ## Which movie has recieved maximum number of user ratings?

# %%
group= merged_movie_rating.groupby('title')['userId'].count()

# %%
max_rated_movie = group.idxmax()

# %%
max_rated_movie
# Out:
# 'Forrest Gump (1994)'

# %%
print(merged_movie_rating[merged_movie_rating['movieId'] == max_rated_movie]['title'].unique())
# Out:
# []

# %%
merged_movie_rating[merged_movie_rating['movieId'] == max_rated_movie]['title']
# Out:
# Series([], Name: title, dtype: object)

# %%
merged_movie_rating[]
# Out:
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_10480/2075667658.py", line 1
#     merged_movie_rating[]
#                         ^
# SyntaxError: invalid syntax

# %%
grp = merged_movie_rating.groupby('title')['userId']

# %%
grp.get_group('Forrest Gump (1994)').count()
# Out:
# 329

# %%
grp.get_group('Black Butler: Book of the Atlantic (2017)').count()
# Out:
# 1

# %%
merged_movie_rating[merged_movie_rating['title'] == "Black Butler: Book of the Atlantic (2017)"]
# Out:
#         movieId                                      title  \
# 100831   193581  Black Butler: Book of the Atlantic (2017)
#
#                                  genres  userId  rating   timestamp
# 100831  Action|Animation|Comedy|Fantasy     184     4.0  1537109082

# %%
merged_movie_rating.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
df_tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
df_movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
merged_movie_tags = pd.merge(df_movies,df_tags,on = "movieId")

# %%
merged_movie_tags.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        2    Jumanji (1995)                   Adventure|Children|Fantasy
# 4        2    Jumanji (1995)                   Adventure|Children|Fantasy
#
#    userId               tag   timestamp
# 0     336             pixar  1139045764
# 1     474             pixar  1137206825
# 2     567               fun  1525286013
# 3      62           fantasy  1528843929
# 4      62  magic board game  1528843932

# %%
merged_movie_tags.shape
# Out:
# (3683, 6)

# %% [markdown]
# ## Select all the correct tags submitted by users to "Matrix, The (1999)" movie?

# %%
merged_movie_tags[merged_movie_tags['title']=="Matrix, The (1999)"]['tag'].unique()
# Out:
# array(['martial arts', 'sci-fi', 'alternate universe', 'philosophy',
#        'post apocalyptic'], dtype=object)

# %%
merged_movie_rating['title'].value_counts()
# Out:
# title
# Forrest Gump (1994)                      329
# Shawshank Redemption, The (1994)         317
# Pulp Fiction (1994)                      307
# Silence of the Lambs, The (1991)         279
# Matrix, The (1999)                       278
#                                         ...
# We're Back! A Dinosaur's Story (1993)      1
# American Hardcore (2006)                   1
# Shanghai Surprise (1986)                   1
# Let's Get Harry (1986)                     1
# Andrew Dice Clay: Dice Rules (1991)        1
# Name: count, Length: 9719, dtype: int64

# %%
a=merged_movie_rating[merged_movie_rating['userId'].duplicated()]

# %%
a['title'].value_counts()
# Out:
# title
# Forrest Gump (1994)                       326
# Pulp Fiction (1994)                       305
# Shawshank Redemption, The (1994)          304
# Silence of the Lambs, The (1991)          278
# Matrix, The (1999)                        278
#                                          ...
# Born in East L.A. (1987)                    1
# Best Seller (1987)                          1
# City of Men (Cidade dos Homens) (2007)      1
# Snow Angels (2007)                          1
# Andrew Dice Clay: Dice Rules (1991)         1
# Name: count, Length: 9718, dtype: int64

# %%
merged_movie_tags.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        2    Jumanji (1995)                   Adventure|Children|Fantasy
# 4        2    Jumanji (1995)                   Adventure|Children|Fantasy
#
#    userId               tag   timestamp
# 0     336             pixar  1139045764
# 1     474             pixar  1137206825
# 2     567               fun  1525286013
# 3      62           fantasy  1528843929
# 4      62  magic board game  1528843932

# %%
merged_movie_rating.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
df_link[df_link['tmdbId'].isnull()]
# Out:
#       movieId  imdbId  tmdbId
# 624       791  113610     NaN
# 843      1107  102336     NaN
# 2141     2851   81454     NaN
# 3027     4051   56600     NaN
# 5532    26587   92337     NaN
# 5854    32600  377059     NaN
# 6059    40697  105946     NaN
# 7382    79299  874957     NaN

# %%
df_movies.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
df_ratings.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
df_tags.isnull().sum()
# Out:
# userId       0
# movieId      0
# tag          0
# timestamp    0
# dtype: int64

# %%
merged_movie_rating.columns
# Out:
# Index(['movieId', 'title', 'genres', 'userId', 'rating', 'timestamp'], dtype='object')

# %%
merged_movie_rating.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %% [markdown]
# ## What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?

# %%
merged_movie_rating[merged_movie_rating['title']=="Terminator 2: Judgment Day (1991)"]['rating'].mean()
# Out:
# 3.970982142857143

# %%
merged_movie_rating.shape
# Out:
# (100836, 6)

# %%
dist=merged_movie_rating[merged_movie_rating['title']=='Fight Club (1999)']['rating'].tolist()

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?

# %%
plt.hist(dist, bins=10)
plt.title('Distribution of User Ratings for Fight Club (1999)')
plt.xlabel('Rating')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Summary stats
print(f"Mean rating: {merged_movie_rating['rating'].mean()}")
print(f"Median rating: {merged_movie_rating['rating'].median()}")
print(f"Mode rating: {merged_movie_rating['rating'].mode()[0]}") 
print(f"Standard deviation: {merged_movie_rating['rating'].std()}")
# Out:
# Mean rating: 3.501556983616962
# Median rating: 3.5
# Mode rating: 4.0
# Standard deviation: 1.042529239060635

# %%
a=merged_movie_rating[merged_movie_rating['title']=='Fight Club (1999)']

# %%
a['rating'].mean()
# Out:
# 4.272935779816514

# %%
ratings_group = merged_movie_rating.groupby('movieId')['rating'].agg(['count','mean'])

# %%
ratings_group
# Out:
#          count      mean
# movieId
# 1          215  3.920930
# 2          110  3.431818
# 3           52  3.259615
# 4            7  2.357143
# 5           49  3.071429
# ...        ...       ...
# 193581       1  4.000000
# 193583       1  3.500000
# 193585       1  3.500000
# 193587       1  3.500000
# 193609       1  4.000000
#
# [9724 rows x 2 columns]

# %%
ratings_group = ratings_group[ratings_group['count'] > 50]

# %%
ratings_group
# Out:
#          count      mean
# movieId
# 1          215  3.920930
# 2          110  3.431818
# 3           52  3.259615
# 6          102  3.946078
# 7           54  3.185185
# ...        ...       ...
# 106782      54  3.916667
# 109374      52  3.778846
# 109487      73  3.993151
# 112852      59  4.050847
# 122904      54  3.833333
#
# [436 rows x 2 columns]

# %%
movie_data = merged_movie_rating.merge(ratings_group, left_on='movieId', right_index=True)

# %%
movie_data
# Out:
#        movieId             title                                       genres  \
# 0            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# ...        ...               ...                                          ...
# 98310   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98311   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98312   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98313   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98314   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
#
#        userId  rating   timestamp  count      mean
# 0           1     4.0   964982703    215  3.920930
# 1           5     4.0   847434962    215  3.920930
# 2           7     4.5  1106635946    215  3.920930
# 3          15     2.5  1510577970    215  3.920930
# 4          17     4.5  1305696483    215  3.920930
# ...       ...     ...         ...    ...       ...
# 98310     561     2.0  1491095067     54  3.833333
# 98311     586     4.0  1529899267     54  3.833333
# 98312     596     4.0  1535709074     54  3.833333
# 98313     599     3.5  1519457935     54  3.833333
# 98314     610     3.0  1493845981     54  3.833333
#
# [40660 rows x 8 columns]

# %%
movie_data = movie_data[movie_data['count'] > 50]

# %%
movie_data
# Out:
#        movieId             title                                       genres  \
# 0            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# ...        ...               ...                                          ...
# 98310   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98311   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98312   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98313   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98314   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
#
#        userId  rating   timestamp  count      mean
# 0           1     4.0   964982703    215  3.920930
# 1           5     4.0   847434962    215  3.920930
# 2           7     4.5  1106635946    215  3.920930
# 3          15     2.5  1510577970    215  3.920930
# 4          17     4.5  1305696483    215  3.920930
# ...       ...     ...         ...    ...       ...
# 98310     561     2.0  1491095067     54  3.833333
# 98311     586     4.0  1529899267     54  3.833333
# 98312     596     4.0  1535709074     54  3.833333
# 98313     599     3.5  1519457935     54  3.833333
# 98314     610     3.0  1493845981     54  3.833333
#
# [40660 rows x 8 columns]

# %%
movie_data['mean'].max()
# Out:
# 4.429022082018927

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_data= pd.merge(df_movies,ratings_group,left_on="movieId",right_index=True)

# %%
movies_data.shape
# Out:
# (436, 5)

# %%
movies_data.head()
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
# 5        6              Heat (1995)
# 6        7           Sabrina (1995)
#
#                                         genres  count      mean
# 0  Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                   Adventure|Children|Fantasy    110  3.431818
# 2                               Comedy|Romance     52  3.259615
# 5                        Action|Crime|Thriller    102  3.946078
# 6                               Comedy|Romance     54  3.185185

# %%
movies_data['mean'].max()
# Out:
# 4.429022082018927

# %%
movies_data[movies_data['mean']=='4.429022']
# Out:
# Empty DataFrame
# Columns: [movieId, title, genres, count, mean]
# Index: []

# %% [markdown]
# ## Which movie is the most popular based on  average user ratings?

# %%
movies_data.sort_values('mean', ascending=False).head(1)
# Out:
#      movieId                             title       genres  count      mean
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama    317  4.429022

# %%
top_movies = movies_data.sort_values('count', ascending=False).head(5)

# %% [markdown]
# ## Select all the correct options which comes under top 5 popular movies based on number of user ratings.

# %%
top_movies
# Out:
#       movieId                             title                       genres  \
# 314       356               Forrest Gump (1994)     Comedy|Drama|Romance|War
# 277       318  Shawshank Redemption, The (1994)                  Crime|Drama
# 257       296               Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 510       593  Silence of the Lambs, The (1991)        Crime|Horror|Thriller
# 1939     2571                Matrix, The (1999)       Action|Sci-Fi|Thriller
#
#       count      mean
# 314     329  4.164134
# 277     317  4.429022
# 257     307  4.197068
# 510     279  4.161290
# 1939    278  4.192446

# %%
Sci = movies_data[movies_data['genres'].str.contains("Sci-Fi")]

# %%
Sci = Sci.sort_values('count',ascending=False)

# %%
Sci
# Out:
#       movieId                                              title  \
# 1939     2571                                 Matrix, The (1999)
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 418       480                               Jurassic Park (1993)
# 507       589                  Terminator 2: Judgment Day (1991)
# 898      1196  Star Wars: Episode V - The Empire Strikes Back...
# ...       ...                                                ...
# 8691   122904                                    Deadpool (2016)
# 144       172                             Johnny Mnemonic (1995)
# 2029     2701                              Wild Wild West (1999)
# 559       673                                   Space Jam (1996)
# 6209    45499                       X-Men: The Last Stand (2006)
#
#                                                  genres  count      mean
# 1939                             Action|Sci-Fi|Thriller    278  4.192446
# 224                             Action|Adventure|Sci-Fi    251  4.231076
# 418                    Action|Adventure|Sci-Fi|Thriller    238  3.750000
# 507                                       Action|Sci-Fi    224  3.970982
# 898                             Action|Adventure|Sci-Fi    211  4.215640
# ...                                                 ...    ...       ...
# 8691                     Action|Adventure|Comedy|Sci-Fi     54  3.833333
# 144                              Action|Sci-Fi|Thriller     53  2.679245
# 2029                       Action|Comedy|Sci-Fi|Western     53  2.207547
# 559   Adventure|Animation|Children|Comedy|Fantasy|Sc...     53  2.707547
# 6209                             Action|Sci-Fi|Thriller     52  3.355769
#
# [88 rows x 5 columns]

# %%
S_title = Sci.iloc[2]

# %% [markdown]
# ## Which Sci-Fi movie is "third most popular" based on the number of user ratings?

# %%
S_title['title']
# Out:
# 'Jurassic Park (1993)'

# %%
df_link.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
link_data = pd.merge(movies_data,df_link,on="movieId")

# %%
link_data
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# 4                                 Comedy|Romance     54  3.185185   114319
# ..                                           ...    ...       ...      ...
# 431                           Comedy|Crime|Drama     54  3.916667   993846
# 432                                 Comedy|Drama     52  3.778846  2278388
# 433                                  Sci-Fi|IMAX     73  3.993151   816692
# 434                      Action|Adventure|Sci-Fi     59  4.050847  2015381
# 435               Action|Adventure|Comedy|Sci-Fi     54  3.833333  1431045
#
#        tmdbId
# 0       862.0
# 1      8844.0
# 2     15602.0
# 3       949.0
# 4     11860.0
# ..        ...
# 431  106646.0
# 432  120467.0
# 433  157336.0
# 434  118340.0
# 435  293660.0
#
# [436 rows x 7 columns]

# %%
link_data[link_data['movieId']==47]
# Out:
#     movieId                        title            genres  count      mean  \
# 16       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller    203  3.975369
#
#     imdbId  tmdbId
# 16  114369   807.0

# %%
link_data['imdbId'].max()
# Out:
# 2278388

# %%
df_ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df_link
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
df_tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
movies_data
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8305   106782   Wolf of Wall Street, The (2013)
# 8372   109374  Grand Budapest Hotel, The (2014)
# 8376   109487               Interstellar (2014)
# 8475   112852    Guardians of the Galaxy (2014)
# 8691   122904                   Deadpool (2016)
#
#                                            genres  count      mean
# 0     Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                      Adventure|Children|Fantasy    110  3.431818
# 2                                  Comedy|Romance     52  3.259615
# 5                           Action|Crime|Thriller    102  3.946078
# 6                                  Comedy|Romance     54  3.185185
# ...                                           ...    ...       ...
# 8305                           Comedy|Crime|Drama     54  3.916667
# 8372                                 Comedy|Drama     52  3.778846
# 8376                                  Sci-Fi|IMAX     73  3.993151
# 8475                      Action|Adventure|Sci-Fi     59  4.050847
# 8691               Action|Adventure|Comedy|Sci-Fi     54  3.833333
#
# [436 rows x 5 columns]

# %%
df_link
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
import requests

# %%
import numpy as np
from bs4 import BeautifulSoup

# %%
sc-5931bdee-1 gVydpF

# %%
rating= soup.find('span',attrs={'class':'sc-5931bdee-1 gVydpF'})

# %%
rating.text
# Out:
# '7.1'

# %%
df_link

# %%
URLS = []
for i in link_data['imdbId']:
    URL = f"https://www.imdb.com/title/tt0{i}/ratings/?ref_=tt_ov_rt"
    URLS.append(URL)

# %%
for i in URLS:
    url = i
    print(url)
# Out:
# https://www.imdb.com/title/tt0114709/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113497/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113228/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113277/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0114319/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113189/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112346/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112641/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0114388/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112281/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113161/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113627/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0114746/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112431/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112818/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112697/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0114369/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0114148/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0114814/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113862/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0116367/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0115759/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0116483/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112573/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt075314/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0115685/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112442/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112384/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112462/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112642/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112715/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112740/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112851/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0112864/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113071/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113481/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113492/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0113957/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0114898/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109445/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109635/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109686/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109707/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110148/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt076759/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110322/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110632/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0114069/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110413/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110912/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110932/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0111282/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0111070/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0111161/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0111280/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0108550/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0114924/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109040/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109444/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109446/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109506/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109830/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109831/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110357/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110475/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110478/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0110622/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0111257/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0111503/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0106220/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109254/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0109439/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0106582/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0106598/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0106673/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0106697/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0106918/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0106977/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107144/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107206/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107290/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107362/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107614/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107818/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107822/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107977/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0108052/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0108160/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt083658/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107688/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0108333/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0108358/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0108399/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt099785/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt099653/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0103639/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0103064/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt099348/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt096895/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0102926/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt029583/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0101414/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt032910/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0100405/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0116282/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0117060/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0116136/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0117705/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0117979/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0117500/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0117998/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt057012/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0117951/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0116629/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0115798/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0116213/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0117218/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt068646/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt052357/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt047396/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt053125/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt034583/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt032138/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt033467/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt062622/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt038650/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt058331/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt059742/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt095016/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt067992/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt095159/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt079470/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0105236/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt091763/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt083866/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt092099/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt096754/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt071853/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0108598/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt073486/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt080684/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt093779/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt082971/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt088846/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt090605/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt060196/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt050083/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt066921/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt056592/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt078788/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt086190/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt099685/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt078748/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0106308/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt054215/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt080455/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt071562/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt093058/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt086879/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt075686/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt070735/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt088247/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt097165/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt061722/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt071315/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt081505/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt092005/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0107048/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt088763/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt061512/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt072431/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt032455/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt088258/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt097576/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt097351/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt064115/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt098635/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0117731/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt099423/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt084726/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0103776/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt077631/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt073195/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0116996/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0116695/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt093822/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0117571/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119008/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119528/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119229/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0118655/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119116/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119567/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0118880/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119094/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119654/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0118884/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0118571/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt099810/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119488/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119174/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0118842/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119164/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0118971/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119177/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120201/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120382/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119217/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120338/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0118715/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120888/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0119822/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120591/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0129387/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt075148/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt095953/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt088847/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt070047/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt093409/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt089218/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120746/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt096874/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt099088/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120815/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt097523/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt061852/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt048280/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt097757/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt088161/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt087469/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120611/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt094721/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt094226/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0104257/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt099487/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0104952/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120789/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0118799/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120586/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120660/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120623/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0128445/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0138097/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt088011/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt090555/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0151804/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt063442/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120735/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0133093/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0147800/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0126886/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120616/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120915/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt078346/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt073629/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0125439/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0145660/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0130827/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt099052/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0158983/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120891/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0163651/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0185937/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120663/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt087332/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0167404/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt080339/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt094737/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt085334/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0169547/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0100802/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt091042/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt058150/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0137523/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt093870/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt096438/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120601/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt094012/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120655/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0162661/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120363/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120689/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0175880/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0177789/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0105793/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0195685/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt077975/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt075860/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0146882/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0102057/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt093773/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0144084/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt080487/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0172495/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120755/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt071230/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0187078/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120630/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0187393/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120903/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0181875/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0218839/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0212338/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0180093/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0160127/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0217869/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0190332/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0208092/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0207201/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0162222/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0212346/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0190590/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0181865/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0209144/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0221027/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0243155/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt086250/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0126029/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0203009/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0212720/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0250494/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0230600/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0139654/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0196229/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0166924/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0246578/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0198781/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0241527/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0240772/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0211915/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0265666/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120737/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0268978/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0268380/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0259446/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0145487/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0121765/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0258463/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0181689/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0120912/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0295178/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0286106/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0245429/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0310793/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0295297/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0167261/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0217505/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0264464/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0317248/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0290334/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0234215/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0315327/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0266543/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0317740/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0289043/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0325980/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0335266/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0332379/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0327056/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0266697/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0242653/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0314331/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0325710/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0319061/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0167260/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0338013/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0378194/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0298148/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0304141/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0316654/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0357413/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0343818/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0372183/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0365748/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0317705/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0405159/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0367594/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0401792/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0121766/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0356910/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0372784/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0396269/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0405422/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0330373/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0363771/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0434409/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0376994/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0383574/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0449059/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0443453/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0457430/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0407887/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0206634/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0482571/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0381061/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0450259/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0382932/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0425112/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0416449/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0478311/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0449088/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0373889/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0440963/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0829482/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0477348/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0480249/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0467406/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0468569/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0371746/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0441773/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0910970/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01010048/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0361748/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0796366/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01049413/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01119646/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0417741/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01136608/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01156398/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0499549/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0988045/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01130884/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0892769/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0435761/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01375666/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01285016/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01504320/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0848228/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01392170/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01345836/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01853728/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0993846/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt02278388/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt0816692/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt02015381/ratings/?ref_=tt_ov_rt
# https://www.imdb.com/title/tt01431045/ratings/?ref_=tt_ov_rt

# %%
import numpy as np

# %%
from tqdm import tqdm

# %%
ratings_ = []
for i in tqdm(URLS):
    URL = i
    request_header={'content-type': 'text/plain;charset=UTF-8',
                'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
                'Accept-Encoding': 'gzip, deflate, br'}
    response= requests.get(URL,headers=request_header)
    html_code=response.text
    soup = BeautifulSoup(html_code)
    containers = soup.find_all('div',attrs={'class':'sc-f056af46-3 dzYxjh'})
    for container in containers:
        rating= container.find('span',attrs={'class':'sc-5931bdee-1 gVydpF'})
        if rating is None:
            ratings_.append(np.NaN)
        else:
            ratings_.append(rating.text)  
            
tqdm.pandas()
#df['ratings'] = df['URL'].progress_apply(scrape_ratings)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 436/436 [07:56<00:00,  1.09s/it]

# %%
df_ratings = pd.Series(ratings_)

# %%
df_rating = df_ratings.dropna()

# %%
len(df_rating)
# Out:
# 311

# %%
Ratings = pd.read_csv("IDMD_rating.csv")

# %%
Ratings.columns=["imdb_rating"]

# %%
Ratings
# Out:
#      imdb_rating
# 0            8.3
# 1            7.1
# 2            6.6
# 3            8.3
# 4            6.3
# ..           ...
# 431          8.2
# 432          NaN
# 433          8.7
# 434          NaN
# 435          NaN
#
# [436 rows x 1 columns]

# %%
final_data =pd.concat([link_data,Ratings],axis=1)

# %%
final_data
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# 4                                 Comedy|Romance     54  3.185185   114319
# ..                                           ...    ...       ...      ...
# 431                           Comedy|Crime|Drama     54  3.916667   993846
# 432                                 Comedy|Drama     52  3.778846  2278388
# 433                                  Sci-Fi|IMAX     73  3.993151   816692
# 434                      Action|Adventure|Sci-Fi     59  4.050847  2015381
# 435               Action|Adventure|Comedy|Sci-Fi     54  3.833333  1431045
#
#        tmdbId  imdb_rating
# 0       862.0          8.3
# 1      8844.0          7.1
# 2     15602.0          6.6
# 3       949.0          8.3
# 4     11860.0          6.3
# ..        ...          ...
# 431  106646.0          8.2
# 432  120467.0          NaN
# 433  157336.0          8.7
# 434  118340.0          NaN
# 435  293660.0          NaN
#
# [436 rows x 8 columns]

# %%
final_data['imdb_rating'].value_counts()
# Out:
# imdb_rating
# 7.6    20
# 7.5    19
# 7.7    19
# 7.3    18
# 7.1    15
# 7.2    15
# 7.9    15
# 8.2    14
# 8.0    14
# 6.5    13
# 6.9    13
# 7.4    12
# 8.3    11
# 8.1    10
# 7.0    10
# 6.8    10
# 6.6     9
# 8.6     8
# 7.8     8
# 6.7     7
# 8.5     7
# 6.2     5
# 6.4     5
# 5.6     4
# 6.3     4
# 8.8     3
# 9.0     3
# 6.1     3
# 8.4     3
# 6.0     2
# 8.9     2
# 5.4     2
# 8.7     2
# 5.3     1
# 9.3     1
# 5.5     1
# 5.7     1
# 4.9     1
# Name: count, dtype: int64

# %%
final_data[final_data['imdb_rating'].isnull()]
# Out:
#      movieId                                      title  \
# 24       111                         Taxi Driver (1976)
# 44       260  Star Wars: Episode IV - A New Hope (1977)
# 88       541                        Blade Runner (1982)
# 93       586                          Home Alone (1990)
# 94       587                               Ghost (1990)
# ..       ...                                        ...
# 429    91529              Dark Knight Rises, The (2012)
# 430    99114                    Django Unchained (2012)
# 432   109374           Grand Budapest Hotel, The (2014)
# 434   112852             Guardians of the Galaxy (2014)
# 435   122904                            Deadpool (2016)
#
#                                     genres  count      mean   imdbId  \
# 24                    Crime|Drama|Thriller    104  4.105769    75314
# 44                 Action|Adventure|Sci-Fi    251  4.231076    76759
# 88                  Action|Sci-Fi|Thriller    124  4.100806    83658
# 93                         Children|Comedy    116  2.995690    99785
# 94   Comedy|Drama|Fantasy|Romance|Thriller    115  3.434783    99653
# ..                                     ...    ...       ...      ...
# 429            Action|Adventure|Crime|IMAX     76  3.993421  1345836
# 430                   Action|Drama|Western     71  3.943662  1853728
# 432                           Comedy|Drama     52  3.778846  2278388
# 434                Action|Adventure|Sci-Fi     59  4.050847  2015381
# 435         Action|Adventure|Comedy|Sci-Fi     54  3.833333  1431045
#
#        tmdbId  imdb_rating
# 24      103.0          NaN
# 44       11.0          NaN
# 88       78.0          NaN
# 93      771.0          NaN
# 94      251.0          NaN
# ..        ...          ...
# 429   49026.0          NaN
# 430   68718.0          NaN
# 432  120467.0          NaN
# 434  118340.0          NaN
# 435  293660.0          NaN
#
# [126 rows x 8 columns]

# %% [markdown]
# ## Mention the movieId of the movie which has the highest IMDB rating.

# %%
high_rat = final_data.sort_values('imdb_rating', ascendin`g=False)

# %%
high_rat.iloc[0]['movieId']
# Out:
# 318

# %%
ratings_ = []
  
for imdbId in tqdm(list1):
  
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    url = f"https://www.imdb.com/title/tt{new_id}/ratings/?ref_=tt_ov_rt"
    
    request_header = {'Content-Type': 'text/html; charset=UTF-8',
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
                      
    response = requests.get(url, headers=request_header)  
    soup = BeautifulSoup(response.text)
    
    rating = soup.find('span', attrs={'class': 'sc-5931bdee-1 gVydpF'})
    
    if rating:
        ratings_.append(float(rating.text)) 
    else:
        ratings_.append(np.nan)

tqdm.pandas()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 436/436 [10:49<00:00,  1.49s/it]

# %%
Ratings1=pd.DataFrame(ratings_)

# %%
Ratings1.columns=['imdb_rating1']

# %%
Ratings1
# Out:
#      imdb_rating1
# 0             8.3
# 1             7.1
# 2             6.6
# 3             8.3
# 4             6.3
# ..            ...
# 431           8.2
# 432           8.1
# 433           8.7
# 434           8.0
# 435           8.0
#
# [436 rows x 1 columns]

# %%
final_data =pd.concat([link_data,Ratings1],axis=1)

# %%
final_data
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# 4                                 Comedy|Romance     54  3.185185   114319
# ..                                           ...    ...       ...      ...
# 431                           Comedy|Crime|Drama     54  3.916667   993846
# 432                                 Comedy|Drama     52  3.778846  2278388
# 433                                  Sci-Fi|IMAX     73  3.993151   816692
# 434                      Action|Adventure|Sci-Fi     59  4.050847  2015381
# 435               Action|Adventure|Comedy|Sci-Fi     54  3.833333  1431045
#
#        tmdbId  imdb_rating1
# 0       862.0           8.3
# 1      8844.0           7.1
# 2     15602.0           6.6
# 3       949.0           8.3
# 4     11860.0           6.3
# ..        ...           ...
# 431  106646.0           8.2
# 432  120467.0           8.1
# 433  157336.0           8.7
# 434  118340.0           8.0
# 435  293660.0           8.0
#
# [436 rows x 8 columns]

# %% [markdown]
# ## Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.

# %%
scifi_df = final_data[final_data['genres'].str.contains('Sci-Fi')]

# %%
scifi_df = scifi_df.sort_values('imdb_rating1', ascending=False)

# %%
top_scifi_id = scifi_df.iloc[0]['movieId']
print(top_scifi_id)
# Out:
# 79132
